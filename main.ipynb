# %%
from GA import *
from Problems import *
from utils import *
import matplotlib.pyplot as plt
import random
np.random.seed(42)
random.seed(42)

# %% [markdown]
# ## Example use

# %%
a = Population("G1", config_file=f"inputs/params_g1.cfg", penalty=True)

# %%
a.evolve("GA")

# %%
population_stats = a.get_population_statistics()
print(population_stats)
# Out:
# {1: {'best_fitness': -17.34779626626429,
#   'best_fitness_with_penalty': 834.1525793453802,
#   'weighted_penalty': 851.5003756116445,
#   'unweighted_penalty': 57.10680732291433,
#   'num_violations': 6},
#  2: {'best_fitness': -1.857932121025323,
#   'best_fitness_with_penalty': 91.53273797552185,
#   'weighted_penalty': 93.39067009654718,
#   'unweighted_penalty': 8.513529433490254,
#   'num_violations': 2},
#  3: {'best_fitness': -2.1427378371069867,
#   'best_fitness_with_penalty': 93.58685393089597,
#   'weighted_penalty': 95.72959176800296,
#   'unweighted_penalty': 8.199825645130668,
#   'num_violations': 2},
#  4: {'best_fitness': -2.4257985482213646,
#   'best_fitness_with_penalty': 18.387342118566995,
#   'weighted_penalty': 20.81314066678836,
#   'unweighted_penalty': 3.0360799727264784,
#   'num_violations': 2},
#  5: {'best_fitness': -2.1923177329177026,
#   'best_fitness_with_penalty': 100.03227901978926,
#   'weighted_penalty': 102.22459675270696,
#   'unweighted_penalty': 8.084875312112612,
#   'num_violations': 2},
#  6: {'best_fitness': -2.460245768435459,
#   'best_fitness_with_penalty': 103.15145407027602,
#   'weighted_penalty': 105.61169983871147,
#   'unweighted_penalty': 8.0,
#   'num_violations': 1},
#  7: {'best_fitness': -3.0,
#   'best_fitness_with_penalty': 106.3175101302655,
#   'weighted_penalty': 109.3175101302655,
#   'unweighted_penalty': 8.0,
#   'num_violations': 1},
#  8: {'best_fitness': -3.0,
#   'best_fitness_with_penalty': 110.16250268773148,
#   'weighted_penalty': 113.16250268773148,
#   'unweighted_penalty': 8.0,
#   'num_violations': 1},
#  9: {'best_fitness': -5.928717778608905,
#   'best_fitness_with_penalty': 127.86158950514127,
#   'weighted_penalty': 133.79030728375017,
#   'unweighted_penalty': 11.571017144212057,
#   'num_violations': 3},
#  10: {'best_fitness': -3.8149738791237278,
#   'best_fitness_with_penalty': 5.477950842710556,
#   'weighted_penalty': 9.292924721834284,
#   'unweighted_penalty': 0.05805286552431266,
#   'num_violations': 1},
#  11: {'best_fitness': -3.8677788422015773,
#   'best_fitness_with_penalty': 5.326013302191116,
#   'weighted_penalty': 9.193792144392694,
#   'unweighted_penalty': 0.0062374779602580865,
#   'num_violations': 1},
#  12: {'best_fitness': -4.026205024919619,
#   'best_fitness_with_penalty': 5.171794975080381,
#   'weighted_penalty': 9.198,
#   'unweighted_penalty': 0,
#   'num_violations': 0},
#  13: {'best_fitness': -3.9211269805606737,
#   'best_fitness_with_penalty': 5.294873019439327,
#   'weighted_penalty': 9.216000000000001,
#   'unweighted_penalty': 0,
#   'num_violations': 0},
#  14: {'best_fitness': -3.9123418360537245,
#   'best_fitness_with_penalty': 5.321658163946275,
#   'weighted_penalty': 9.234,
#   'unweighted_penalty': 0,
#   'num_violations': 0},
#  15: {'best_fitness': -4.059253381794603,
#   'best_fitness_with_penalty': 5.192746618205398,
#   'weighted_penalty': 9.252,
#   'unweighted_penalty': 0,
#   'num_violations': 0},
#  16: {'best_fitness': -3.798291189456865,
#   'best_fitness_with_penalty': 5.471708810543134,
#   'weighted_penalty': 9.27,
#   'unweighted_penalty': 0,
#   'num_violations': 0},
#  17: {'best_fitness': -3.800718852162087,
#   'best_fitness_with_penalty': 5.487281147837914,
#   'weighted_penalty': 9.288,
#   'unweighted_penalty': 0,
#   'num_violations': 0},
#  18: {'best_fitness': -3.731616035807149,
#   'best_fitness_with_penalty': 5.574383964192852,
#   'weighted_penalty': 9.306000000000001,
#   'unweighted_penalty': 0,
#   'num_violations': 0},
#  19: {'best_fitness': -3.480277062946311,
#   'best_fitness_with_penalty': 6.174692513434225,
#   'weighted_penalty': 9.654969576380536,
#   'unweighted_penalty': 0.1288129456434834,
#   'num_violations': 1},
#  20: {'best_fitness': -3.3641080786296005,
#   'best_fitness_with_penalty': 5.9778919213704,
#   'weighted_penalty': 9.342,
#   'unweighted_penalty': 0,
#   'num_violations': 0},
#  21: {'best_fitness': -3.534927069996869,
#   'best_fitness_with_penalty': 6.420205479681881,
#   'weighted_penalty': 9.95513254967875,
#   'unweighted_penalty': 0.21536502610119695,
#   'num_violations': 1},
#  22: {'best_fitness': -4.251458508056798,
#   'best_fitness_with_penalty': 7.2983721372980614,
#   'weighted_penalty': 11.54983064535486,
#   'unweighted_penalty': 0.6195660320953302,
#   'num_violations': 1},
#  23: {'best_fitness': -3.9203151184827387,
#   'best_fitness_with_penalty': 6.428573485949492,
#   'weighted_penalty': 10.348888604432231,
#   'unweighted_penalty': 0.3174998356430103,
#   'num_violations': 1},
#  24: {'best_fitness': -4.13626506274162,
#   'best_fitness_with_penalty': 6.583016232535854,
#   'weighted_penalty': 10.719281295277474,
#   'unweighted_penalty': 0.44103840209436684,
#   'num_violations': 2},
#  25: {'best_fitness': -3.9221905228925293,
#   'best_fitness_with_penalty': 5.953847286514076,
#   'weighted_penalty': 9.876037809406606,
#   'unweighted_penalty': 0.16760917165215605,
#   'num_violations': 2},
#  26: {'best_fitness': -3.8317125756183286,
#   'best_fitness_with_penalty': 6.366104110772546,
#   'weighted_penalty': 10.197816686390874,
#   'unweighted_penalty': 0.26746490701961123,
#   'num_violations': 2},
#  27: {'best_fitness': -3.461795501824757,
#   'best_fitness_with_penalty': 6.688139787525554,
#   'weighted_penalty': 10.14993528935031,
#   'unweighted_penalty': 0.2355925153073496,
#   'num_violations': 2},
#  28: {'best_fitness': -3.6308626995270616,
#   'best_fitness_with_penalty': 6.748455892911816,
#   'weighted_penalty': 10.379318592438878,
#   'unweighted_penalty': 0.3037805461566958,
#   'num_violations': 2},
#  29: {'best_fitness': -2.3926594155193097,
#   'best_fitness_with_penalty': 7.111340584480692,
#   'weighted_penalty': 9.504000000000001,
#   'unweighted_penalty': 0,
#   'num_violations': 0},
#  30: {'best_fitness': -2.980827135103084,
#   'best_fitness_with_penalty': 6.541172864896916,
#   'weighted_penalty': 9.522,
#   'unweighted_penalty': 0,
#   'num_violations': 0},
#  31: {'best_fitness': -2.978907893975496,
#   'best_fitness_with_penalty': 6.561092106024505,
#   'weighted_penalty': 9.540000000000001,
#   'unweighted_penalty': 0,
#   'num_violations': 0},
#  32: {'best_fitness': -3.5599455896829455,
#   'best_fitness_with_penalty': 5.998054410317055,
#   'weighted_penalty': 9.558,
#   'unweighted_penalty': 0,
#   'num_violations': 0},
#  33: {'best_fitness': -2.5494103420097036,
#   'best_fitness_with_penalty': 8.567413250706325,
#   'weighted_penalty': 11.11682359271603,
#   'unweighted_penalty': 0.43092799108999635,
#   'num_violations': 2},
#  34: {'best_fitness': -2.4833859209459415,
#   'best_fitness_with_penalty': 10.427856403106802,
#   'weighted_penalty': 12.911242324052743,
#   'unweighted_penalty': 0.8872801133805699,
#   'num_violations': 2},
#  35: {'best_fitness': -2.2301439511984658,
#   'best_fitness_with_penalty': 11.256913786727532,
#   'weighted_penalty': 13.487057737925998,
#   'unweighted_penalty': 0.9948852046214591,
#   'num_violations': 2},
#  36: {'best_fitness': -2.3726698319833517,
#   'best_fitness_with_penalty': 11.910092855632602,
#   'weighted_penalty': 14.282762687615953,
#   'unweighted_penalty': 1.1056580521809538,
#   'num_violations': 2},
#  37: {'best_fitness': -2.4339119873633046,
#   'best_fitness_with_penalty': 10.07361393705515,
#   'weighted_penalty': 12.507525924418454,
#   'unweighted_penalty': 0.6560990927368078,
#   'num_violations': 1},
#  38: {'best_fitness': -3.271047131637169,
#   'best_fitness_with_penalty': 12.758063604063931,
#   'weighted_penalty': 16.0291107357011,
#   'unweighted_penalty': 1.487916193066285,
#   'num_violations': 3},
#  39: {'best_fitness': -2.962717377350024,
#   'best_fitness_with_penalty': 13.447390790151623,
#   'weighted_penalty': 16.410108167501647,
#   'unweighted_penalty': 1.4533749140122953,
#   'num_violations': 3},
#  40: {'best_fitness': -2.780615307101135,
#   'best_fitness_with_penalty': 10.49076344993219,
#   'weighted_penalty': 13.271378757033325,
#   'unweighted_penalty': 0.838988471364173,
#   'num_violations': 2},
#  41: {'best_fitness': -2.4870488649486218,
#   'best_fitness_with_penalty': 8.004467376171192,
#   'weighted_penalty': 10.491516241119813,
#   'unweighted_penalty': 0.23736485937900842,
#   'num_violations': 3},
#  42: {'best_fitness': -2.497276079244681,
#   'best_fitness_with_penalty': 8.482257111414095,
#   'weighted_penalty': 10.979533190658776,
#   'unweighted_penalty': 0.3366915402017852,
#   'num_violations': 2},
#  43: {'best_fitness': -2.5291042956177034,
#   'best_fitness_with_penalty': 8.12465185270547,
#   'weighted_penalty': 10.653756148323174,
#   'unweighted_penalty': 0.25331929595105934,
#   'num_violations': 1},
#  44: {'best_fitness': -3.0,
#   'best_fitness_with_penalty': 6.774000000000001,
#   'weighted_penalty': 9.774000000000001,
#   'unweighted_penalty': 0,
#   'num_violations': 0},
#  45: {'best_fitness': -3.5149018002190955,
#   'best_fitness_with_penalty': 6.277098199780906,
#   'weighted_penalty': 9.792000000000002,
#   'unweighted_penalty': 0,
#   'num_violations': 0},
#  46: {'best_fitness': -3.4942905353258458,
#   'best_fitness_with_penalty': 6.315709464674155,
#   'weighted_penalty': 9.81,
#   'unweighted_penalty': 0,
#   'num_violations': 0},
#  47: {'best_fitness': -3.2091011435790353,
#   'best_fitness_with_penalty': 8.281439728649728,
#   'weighted_penalty': 11.490540872228763,
#   'unweighted_penalty': 0.40753083052746764,
#   'num_violations': 2},
#  48: {'best_fitness': -3.0232653678356356,
#   'best_fitness_with_penalty': 6.822734632164364,
#   'weighted_penalty': 9.846,
#   'unweighted_penalty': 0,
#   'num_violations': 0},
#  49: {'best_fitness': -2.935313440830111,
#   'best_fitness_with_penalty': 7.105694242190166,
#   'weighted_penalty': 10.041007683020277,
#   'unweighted_penalty': 0.056775385168973486,
#   'num_violations': 2},
#  50: {'best_fitness': -2.3384906126975404,
#   'best_fitness_with_penalty': 9.371119327166893,
#   'weighted_penalty': 11.709609939864434,
#   'unweighted_penalty': 0.4751813865318508,
#   'num_violations': 2},
#  51: {'best_fitness': -1.4906001363953503,
#   'best_fitness_with_penalty': 9.188738599566182,
#   'weighted_penalty': 10.679338735961533,
#   'unweighted_penalty': 0.21080958443235037,
#   'num_violations': 1},
#  52: {'best_fitness': -3.0,
#   'best_fitness_with_penalty': 6.918000000000001,
#   'weighted_penalty': 9.918000000000001,
#   'unweighted_penalty': 0,
#   'num_violations': 0},
#  53: {'best_fitness': -2.141598275670131,
#   'best_fitness_with_penalty': 7.7944017243298696,
#   'weighted_penalty': 9.936,
#   'unweighted_penalty': 0,
#   'num_violations': 0},
#  54: {'best_fitness': -1.9552836211530251,
#   'best_fitness_with_penalty': 8.135312077030468,
#   'weighted_penalty': 10.090595698183494,
#   'unweighted_penalty': 0.041736730323057525,
#   'num_violations': 1},
#  55: {'best_fitness': -2.579815228172834,
#   'best_fitness_with_penalty': 7.676926145416823,
#   'weighted_penalty': 10.256741373589657,
#   'unweighted_penalty': 0.08313480837548498,
#   'num_violations': 1},
#  56: {'best_fitness': -2.6266205783266217,
#   'best_fitness_with_penalty': 10.117583772322227,
#   'weighted_penalty': 12.744204350648848,
#   'unweighted_penalty': 0.6041343462263661,
#   'num_violations': 2},
#  57: {'best_fitness': -2.943491667250359,
#   'best_fitness_with_penalty': 10.332736105977226,
#   'weighted_penalty': 13.276227773227584,
#   'unweighted_penalty': 0.6382948714311376,
#   'num_violations': 2},
#  58: {'best_fitness': -3.0,
#   'best_fitness_with_penalty': 7.026000000000002,
#   'weighted_penalty': 10.026000000000002,
#   'unweighted_penalty': 0,
#   'num_violations': 0},
#  59: {'best_fitness': -2.4823485762907875,
#   'best_fitness_with_penalty': 11.008485675339175,
#   'weighted_penalty': 13.490834251629963,
#   'unweighted_penalty': 0.7393333167827236,
#   'num_violations': 2},
#  60: {'best_fitness': -2.0352647595929576,
#   'best_fitness_with_penalty': 8.026735240407042,
#   'weighted_penalty': 10.062,
#   'unweighted_penalty': 0,
#   'num_violations': 0},
#  61: {'best_fitness': -2.6057060286044513,
#   'best_fitness_with_penalty': 7.47429397139555,
#   'weighted_penalty': 10.080000000000002,
#   'unweighted_penalty': 0,
#   'num_violations': 0},
#  62: {'best_fitness': -1.9601507094635893,
#   'best_fitness_with_penalty': 8.40276068309535,
#   'weighted_penalty': 10.362911392558939,
#   'unweighted_penalty': 0.07382569189916115,
#   'num_violations': 2},
#  63: {'best_fitness': -2.9131348344514585,
#   'best_fitness_with_penalty': 7.202865165548543,
#   'weighted_penalty': 10.116000000000001,
#   'unweighted_penalty': 0,
#   'num_violations': 0},
#  64: {'best_fitness': -3.0,
#   'best_fitness_with_penalty': 7.133999999999999,
#   'weighted_penalty': 10.133999999999999,
#   'unweighted_penalty': 0,
#   'num_violations': 0},
#  65: {'best_fitness': -2.731137611233316,
#   'best_fitness_with_penalty': 7.420862388766685,
#   'weighted_penalty': 10.152000000000001,
#   'unweighted_penalty': 0,
#   'num_violations': 0},
#  66: {'best_fitness': -2.2070189921630776,
#   'best_fitness_with_penalty': 7.9629810078369205,
#   'weighted_penalty': 10.169999999999998,
#   'unweighted_penalty': 0,
#   'num_violations': 0},
#  67: {'best_fitness': -2.860442279795376,
#   'best_fitness_with_penalty': 7.3275577202046245,
#   'weighted_penalty': 10.188,
#   'unweighted_penalty': 0,
#   'num_violations': 0},
#  68: {'best_fitness': -2.6584335822041805,
#   'best_fitness_with_penalty': 7.547566417795819,
#   'weighted_penalty': 10.206,
#   'unweighted_penalty': 0,
#   'num_violations': 0},
#  69: {'best_fitness': -3.0,
#   'best_fitness_with_penalty': 7.224,
#   'weighted_penalty': 10.224,
#   'unweighted_penalty': 0,
#   'num_violations': 0},
#  70: {'best_fitness': -3.0,
#   'best_fitness_with_penalty': 7.241999999999999,
#   'weighted_penalty': 10.241999999999999,
#   'unweighted_penalty': 0,
#   'num_violations': 0},
#  71: {'best_fitness': -3.0,
#   'best_fitness_with_penalty': 7.260000000000002,
#   'weighted_penalty': 10.260000000000002,
#   'unweighted_penalty': 0,
#   'num_violations': 0},
#  72: {'best_fitness': -3.0,
#   'best_fitness_with_penalty': 7.277999999999999,
#   'weighted_penalty': 10.277999999999999,
#   'unweighted_penalty': 0,
#   'num_violations': 0},
#  73: {'best_fitness': -3.0,
#   'best_fitness_with_penalty': 7.295999999999999,
#   'weighted_penalty': 10.296,
#   'unweighted_penalty': 0,
#   'num_violations': 0},
#  74: {'best_fitness': -3.0,
#   'best_fitness_with_penalty': 7.314,
#   'weighted_penalty': 10.314,
#   'unweighted_penalty': 0,
#   'num_violations': 0},
#  75: {'best_fitness': -3.0,
#   'best_fitness_with_penalty': 7.331999999999999,
#   'weighted_penalty': 10.331999999999999,
#   'unweighted_penalty': 0,
#   'num_violations': 0},
#  76: {'best_fitness': -3.0,
#   'best_fitness_with_penalty': 7.35,
#   'weighted_penalty': 10.35,
#   'unweighted_penalty': 0,
#   'num_violations': 0},
#  77: {'best_fitness': -3.0,
#   'best_fitness_with_penalty': 7.3679999999999986,
#   'weighted_penalty': 10.367999999999999,
#   'unweighted_penalty': 0,
#   'num_violations': 0},
#  78: {'best_fitness': -2.9888997996042423,
#   'best_fitness_with_penalty': 7.855871784897484,
#   'weighted_penalty': 10.844771584501727,
#   'unweighted_penalty': 0.11519211380406319,
#   'num_violations': 2},
#  79: {'best_fitness': -2.9901109905259853,
#   'best_fitness_with_penalty': 7.4744829487228275,
#   'weighted_penalty': 10.464593939248813,
#   'unweighted_penalty': 0.01585383316166289,
#   'num_violations': 1},
#  80: {'best_fitness': -3.0,
#   'best_fitness_with_penalty': 7.421999999999999,
#   'weighted_penalty': 10.421999999999999,
#   'unweighted_penalty': 0,
#   'num_violations': 0},
#  81: {'best_fitness': -3.0,
#   'best_fitness_with_penalty': 7.4399999999999995,
#   'weighted_penalty': 10.44,
#   'unweighted_penalty': 0,
#   'num_violations': 0},
#  82: {'best_fitness': -3.0559722106086924,
#   'best_fitness_with_penalty': 7.729798165904624,
#   'weighted_penalty': 10.785770376513316,
#   'unweighted_penalty': 0.07830261201711833,
#   'num_violations': 1},
#  83: {'best_fitness': -2.991825412921335,
#   'best_fitness_with_penalty': 7.528596668561464,
#   'weighted_penalty': 10.5204220814828,
#   'unweighted_penalty': 0.011372481979095156,
#   'num_violations': 1},
#  84: {'best_fitness': -2.992503682388417,
#   'best_fitness_with_penalty': 7.517920169054822,
#   'weighted_penalty': 10.510423851443239,
#   'unweighted_penalty': 0.004211775934210987,
#   'num_violations': 1},
#  85: {'best_fitness': -2.7018962788254672,
#   'best_fitness_with_penalty': 7.8330087393341135,
#   'weighted_penalty': 10.53490501815958,
#   'unweighted_penalty': 0.0058245084526539915,
#   'num_violations': 1},
#  86: {'best_fitness': -3.0319589360046666,
#   'best_fitness_with_penalty': 7.498041063995332,
#   'weighted_penalty': 10.53,
#   'unweighted_penalty': 0,
#   'num_violations': 0},
#  87: {'best_fitness': -1.8783248089643843,
#   'best_fitness_with_penalty': 8.720386563544762,
#   'weighted_penalty': 10.598711372509147,
#   'unweighted_penalty': 0.012719434549405086,
#   'num_violations': 2},
#  88: {'best_fitness': -3.4101674302976295,
#   'best_fitness_with_penalty': 7.212033783086252,
#   'weighted_penalty': 10.622201213383882,
#   'unweighted_penalty': 0.013993028747745738,
#   'num_violations': 2},
#  89: {'best_fitness': -3.6644132493208796,
#   'best_fitness_with_penalty': 6.968971937626202,
#   'weighted_penalty': 10.633385186947082,
#   'unweighted_penalty': 0.012225876230248301,
#   'num_violations': 2},
#  90: {'best_fitness': -3.554512888847027,
#   'best_fitness_with_penalty': 7.127398592439841,
#   'weighted_penalty': 10.681911481286868,
#   'unweighted_penalty': 0.01950818719932288,
#   'num_violations': 2},
#  91: {'best_fitness': -3.8674442287429858,
#   'best_fitness_with_penalty': 6.862934973067238,
#   'weighted_penalty': 10.730379201810225,
#   'unweighted_penalty': 0.02652716795228895,
#   'num_violations': 2},
#  92: {'best_fitness': -3.39084259484203,
#   'best_fitness_with_penalty': 7.301580479071357,
#   'weighted_penalty': 10.692423073913387,
#   'unweighted_penalty': 0.013110275205782562,
#   'num_violations': 1},
#  93: {'best_fitness': -2.0636487279365414,
#   'best_fitness_with_penalty': 8.92180702121842,
#   'weighted_penalty': 10.985455749154962,
#   'unweighted_penalty': 0.07326744562345941,
#   'num_violations': 1},
#  94: {'best_fitness': -2.9936573679530567,
#   'best_fitness_with_penalty': 7.904696010853353,
#   'weighted_penalty': 10.89835337880641,
#   'unweighted_penalty': 0.05092575138665981,
#   'num_violations': 1},
#  95: {'best_fitness': -3.295897933552387,
#   'best_fitness_with_penalty': 7.396102066447613,
#   'weighted_penalty': 10.692,
#   'unweighted_penalty': 0,
#   'num_violations': 0},
#  96: {'best_fitness': -3.437202034268176,
#   'best_fitness_with_penalty': 9.404578731745357,
#   'weighted_penalty': 12.841780766013532,
#   'unweighted_penalty': 0.3386114848506402,
#   'num_violations': 1},
#  97: {'best_fitness': -2.8825597257711872,
#   'best_fitness_with_penalty': 8.996616435563297,
#   'weighted_penalty': 11.879176161334485,
#   'unweighted_penalty': 0.2356645842580149,
#   'num_violations': 3},
#  98: {'best_fitness': -2.7310327082331813,
#   'best_fitness_with_penalty': 8.179562929221722,
#   'weighted_penalty': 10.910595637454904,
#   'unweighted_penalty': 0.03702671916699085,
#   'num_violations': 1},
#  99: {'best_fitness': -2.544333971929723,
#   'best_fitness_with_penalty': 8.64682360856482,
#   'weighted_penalty': 11.191157580494542,
#   'unweighted_penalty': 0.08936370975255235,
#   'num_violations': 2},
#  100: {'best_fitness': -2.594462150278824,
#   'best_fitness_with_penalty': 8.187537849721176,
#   'weighted_penalty': 10.782,
#   'unweighted_penalty': 0,
#   'num_violations': 0},
#  101: {'best_fitness': -2.936907031700723,
#   'best_fitness_with_penalty': 7.863762215058058,
#   'weighted_penalty': 10.800669246758781,
#   'unweighted_penalty': 0.0001548870416287171,
#   'num_violations': 1},
#  102: {'best_fitness': -2.987446412806279,
#   'best_fitness_with_penalty': 7.83055358719372,
#   'weighted_penalty': 10.818,
#   'unweighted_penalty': 0,
#   'num_violations': 0},
#  103: {'best_fitness': -3.1578824991434393,
#   'best_fitness_with_penalty': 7.678117500856561,
#   'weighted_penalty': 10.836,
#   'unweighted_penalty': 0,
#   'num_violations': 0},
#  104: {'best_fitness': -3.014179142849673,
#   'best_fitness_with_penalty': 7.90312346414727,
#   'weighted_penalty': 10.917302606996943,
#   'unweighted_penalty': 0.01417914284967304,
#   'num_violations': 2},
#  105: {'best_fitness': -3.0329770919150496,
#   'best_fitness_with_penalty': 7.993432831560573,
#   'weighted_penalty': 11.026409923475622,
#   'unweighted_penalty': 0.033713717994884616,
#   'num_violations': 3},
#  106: {'best_fitness': -3.042448679968595,
#   'best_fitness_with_penalty': 7.847551320031405,
#   'weighted_penalty': 10.89,
#   'unweighted_penalty': 0,
#   'num_violations': 0},
#  107: {'best_fitness': -3.0726444770453174,
#   'best_fitness_with_penalty': 7.835355522954682,
#   'weighted_penalty': 10.908,
#   'unweighted_penalty': 0,
#   'num_violations': 0},
#  108: {'best_fitness': -3.2885901028500317,
#   'best_fitness_with_penalty': 7.637409897149968,
#   'weighted_penalty': 10.926,
#   'unweighted_penalty': 0,
#   'num_violations': 0},
#  109: {'best_fitness': -3.199508187834648,
#   'best_fitness_with_penalty': 7.744491812165351,
#   'weighted_penalty': 10.943999999999999,
#   'unweighted_penalty': 0,
#   'num_violations': 0},
#  110: {'best_fitness': -3.2095813298068947,
#   'best_fitness_with_penalty': 7.752418670193105,
#   'weighted_penalty': 10.962,
#   'unweighted_penalty': 0,
#   'num_violations': 0},
#  111: {'best_fitness': -3.254470527390813,
#   'best_fitness_with_penalty': 7.725529472609187,
#   'weighted_penalty': 10.98,
#   'unweighted_penalty': 0,
#   'num_violations': 0},
#  112: {'best_fitness': -2.4847390667204685,
#   'best_fitness_with_penalty': 8.51326093327953,
#   'weighted_penalty': 10.998,
#   'unweighted_penalty': 0,
#   'num_violations': 0},
#  113: {'best_fitness': -3.040297541351803,
#   'best_fitness_with_penalty': 8.193527361045321,
#   'weighted_penalty': 11.233824902397124,
#   'unweighted_penalty': 0.0441387236832913,
#   'num_violations': 1},
#  114: {'best_fitness': -3.082928397612209,
#   'best_fitness_with_penalty': 7.95107160238779,
#   'weighted_penalty': 11.033999999999999,
#   'unweighted_penalty': 0,
#   'num_violations': 0},
#  115: {'best_fitness': -3.290504597081311,
#   'best_fitness_with_penalty': 7.761495402918689,
#   'weighted_penalty': 11.052,
#   'unweighted_penalty': 0,
#   'num_violations': 0},
#  116: {'best_fitness': -2.6717841135511415,
#   'best_fitness_with_penalty': 8.398892546897631,
#   'weighted_penalty': 11.070676660448774,
#   'unweighted_penalty': 0.00014323400177036446,
#   'num_violations': 1},
#  117: {'best_fitness': -2.550731039725489,
#   'best_fitness_with_penalty': 8.53726896027451,
#   'weighted_penalty': 11.088,
#   'unweighted_penalty': 0,
#   'num_violations': 0},
#  118: {'best_fitness': -2.811899572888345,
#   'best_fitness_with_penalty': 8.294100427111655,
#   'weighted_penalty': 11.106,
#   'unweighted_penalty': 0,
#   'num_violations': 0},
#  119: {'best_fitness': -2.966856744727552,
#   'best_fitness_with_penalty': 8.189538241251347,
#   'weighted_penalty': 11.1563949859789,
#   'unweighted_penalty': 0.006676497643268942,
#   'num_violations': 1},
#  120: {'best_fitness': -3.248725445122674,
#   'best_fitness_with_penalty': 7.999273503337769,
#   'weighted_penalty': 11.247998948460443,
#   'unweighted_penalty': 0.0212660732843456,
#   'num_violations': 1},
#  121: {'best_fitness': -3.350535667194354,
#   'best_fitness_with_penalty': 7.932245619899279,
#   'weighted_penalty': 11.282781287093632,
#   'unweighted_penalty': 0.024378195284372465,
#   'num_violations': 1},
#  122: {'best_fitness': -3.6404743833948157,
#   'best_fitness_with_penalty': 7.553702038829552,
#   'weighted_penalty': 11.194176422224368,
#   'unweighted_penalty': 0.0032931149954469746,
#   'num_violations': 1},
#  123: {'best_fitness': -3.6398235471882643,
#   'best_fitness_with_penalty': 7.5598045320519045,
#   'weighted_penalty': 11.199628079240169,
#   'unweighted_penalty': 0.0007371687885290579,
#   'num_violations': 1},
#  124: {'best_fitness': -3.6254546494646274,
#   'best_fitness_with_penalty': 7.588545350535373,
#   'weighted_penalty': 11.214,
#   'unweighted_penalty': 0,
#   'num_violations': 0},
#  125: {'best_fitness': -3.652457023305714,
#   'best_fitness_with_penalty': 7.5795429766942854,
#   'weighted_penalty': 11.232,
#   'unweighted_penalty': 0,
#   'num_violations': 0},
#  126: {'best_fitness': -3.653144993936957,
#   'best_fitness_with_penalty': 7.596855006063043,
#   'weighted_penalty': 11.25,
#   'unweighted_penalty': 0,
#   'num_violations': 0},
#  127: {'best_fitness': -3.758166213163109,
#   'best_fitness_with_penalty': 7.585065887170387,
#   'weighted_penalty': 11.343232100333497,
#   'unweighted_penalty': 0.014636299301176377,
#   'num_violations': 1},
#  128: {'best_fitness': -3.983849582226627,
#   'best_fitness_with_penalty': 7.3021504177733725,
#   'weighted_penalty': 11.286,
#   'unweighted_penalty': 0,
#   'num_violations': 0},
#  129: {'best_fitness': -3.9867999451671707,
#   'best_fitness_with_penalty': 7.3172000548328295,
#   'weighted_penalty': 11.304,
#   'unweighted_penalty': 0,
#   'num_violations': 0},
#  130: {'best_fitness': -3.9964809514939317,
#   'best_fitness_with_penalty': 7.3255190485060675,
#   'weighted_penalty': 11.322,
#   'unweighted_penalty': 0,
#   'num_violations': 0},
#  131: {'best_fitness': -3.9907907265188367,
#   'best_fitness_with_penalty': 7.349209273481163,
#   'weighted_penalty': 11.34,
#   'unweighted_penalty': 0,
#   'num_violations': 0},
#  132: {'best_fitness': -3.6602638969158003,
#   'best_fitness_with_penalty': 8.35337567272132,
#   'weighted_penalty': 12.013639569637121,
#   'unweighted_penalty': 0.11570413453514841,
#   'num_violations': 2},
#  133: {'best_fitness': -2.6789551431491256,
#   'best_fitness_with_penalty': 8.810553000156332,
#   'weighted_penalty': 11.489508143305457,
#   'unweighted_penalty': 0.021133363634692204,
#   'num_violations': 1},
#  134: {'best_fitness': -2.6967257357004972,
#   'best_fitness_with_penalty': 8.69794445901683,
#   'weighted_penalty': 11.394670194717326,
#   'unweighted_penalty': 0.00012821549640418674,
#   'num_violations': 1},
#  135: {'best_fitness': -4.0,
#   'best_fitness_with_penalty': 7.412000000000001,
#   'weighted_penalty': 11.412,
#   'unweighted_penalty': 0,
#   'num_violations': 0},
#  136: {'best_fitness': -4.0,
#   'best_fitness_with_penalty': 7.43,
#   'weighted_penalty': 11.43,
#   'unweighted_penalty': 0,
#   'num_violations': 0},
#  137: {'best_fitness': -4.0,
#   'best_fitness_with_penalty': 7.448,
#   'weighted_penalty': 11.448,
#   'unweighted_penalty': 0,
#   'num_violations': 0},
#  138: {'best_fitness': -2.7964671910023435,
#   'best_fitness_with_penalty': 8.684917114047654,
#   'weighted_penalty': 11.481384305049998,
#   'unweighted_penalty': 0.0028685906646631278,
#   'num_violations': 2},
#  139: {'best_fitness': -2.7727644500106416,
#   'best_fitness_with_penalty': 8.71132415843429,
#   'weighted_penalty': 11.484088608444933,
#   'unweighted_penalty': 1.6502200429955997e-05,
#   'num_violations': 2},
#  140: {'best_fitness': -3.0715418043236364,
#   'best_fitness_with_penalty': 8.454739158343328,
#   'weighted_penalty': 11.526280962666965,
#   'unweighted_penalty': 0.004467403137990174,
#   'num_violations': 2},
#  141: {'best_fitness': -3.069998686428249,
#   'best_fitness_with_penalty': 8.450756437209051,
#   'weighted_penalty': 11.5207551236373,
#   'unweighted_penalty': 0.00013910552221128083,
#   'num_violations': 1},
#  142: {'best_fitness': -2.9081148119999334,
#   'best_fitness_with_penalty': 8.77208455289397,
#   'weighted_penalty': 11.680199364893904,
#   'unweighted_penalty': 0.025023286488066898,
#   'num_violations': 1},
#  143: {'best_fitness': -2.6523356715077653,
#   'best_fitness_with_penalty': 8.943800675422182,
#   'weighted_penalty': 11.596136346929947,
#   'unweighted_penalty': 0.007231128807672849,
#   'num_violations': 1},
#  144: {'best_fitness': -2.867801046645621,
#   'best_fitness_with_penalty': 8.763390051002538,
#   'weighted_penalty': 11.63119109764816,
#   'unweighted_penalty': 0.010275280291911871,
#   'num_violations': 2},
#  145: {'best_fitness': -2.9236056847863736,
#   'best_fitness_with_penalty': 8.668394315213627,
#   'weighted_penalty': 11.592,
#   'unweighted_penalty': 0,
#   'num_violations': 0},
#  146: {'best_fitness': -2.983681614113785,
#   'best_fitness_with_penalty': 8.626318385886215,
#   'weighted_penalty': 11.61,
#   'unweighted_penalty': 0,
#   'num_violations': 0},
#  147: {'best_fitness': -3.019182944742814,
#   'best_fitness_with_penalty': 8.608817055257186,
#   'weighted_penalty': 11.628,
#   'unweighted_penalty': 0,
#   'num_violations': 0},
#  148: {'best_fitness': -2.5547130083065,
#   'best_fitness_with_penalty': 9.101183867499211,
#   'weighted_penalty': 11.65589687580571,
#   'unweighted_penalty': 0.0017522644278133454,
#   'num_violations': 1},
#  149: {'best_fitness': -3.7406397870521175,
#   'best_fitness_with_penalty': 7.963854209341077,
#   'weighted_penalty': 11.704493996393195,
#   'unweighted_penalty': 0.007068630914671968,
#   'num_violations': 1},
#  150: {'best_fitness': -3.756924323499545,
#   'best_fitness_with_penalty': 7.93871501106541,
#   'weighted_penalty': 11.695639334564955,
#   'unweighted_penalty': 0.0023872283457312647,
#   'num_violations': 1},
#  151: {'best_fitness': -4.309468049980404,
#   'best_fitness_with_penalty': 7.408391091326588,
#   'weighted_penalty': 11.717859141306992,
#   'unweighted_penalty': 0.0031057886444954552,
#   'num_violations': 1},
#  152: {'best_fitness': -4.319162718569015,
#   'best_fitness_with_penalty': 7.421598226711937,
#   'weighted_penalty': 11.740760945280952,
#   'unweighted_penalty': 0.003932185635311669,
#   'num_violations': 1},
#  153: {'best_fitness': -4.506055195509257,
#   'best_fitness_with_penalty': 7.2846231485233,
#   'weighted_penalty': 11.790678344032557,
#   'unweighted_penalty': 0.009313188554059283,
#   'num_violations': 2},
#  154: {'best_fitness': -4.137825100592709,
#   'best_fitness_with_penalty': 7.650125612396069,
#   'weighted_penalty': 11.787950712988778,
#   'unweighted_penalty': 0.005791887673890482,
#   'num_violations': 2},
#  155: {'best_fitness': -4.368057518829049,
#   'best_fitness_with_penalty': 7.403942481170951,
#   'weighted_penalty': 11.772,
#   'unweighted_penalty': 0,
#   'num_violations': 0},
#  156: {'best_fitness': -4.47059394803633,
#   'best_fitness_with_penalty': 7.319406051963671,
#   'weighted_penalty': 11.790000000000001,
#   'unweighted_penalty': 0,
#   'num_violations': 0},
#  157: {'best_fitness': -4.227717674804903,
#   'best_fitness_with_penalty': 7.667798926144642,
#   'weighted_penalty': 11.895516600949545,
#   'unweighted_penalty': 0.014587534840926057,
#   'num_violations': 2},
#  158: {'best_fitness': -4.371194655005069,
#   'best_fitness_with_penalty': 7.454805344994932,
#   'weighted_penalty': 11.826,
#   'unweighted_penalty': 0,
#   'num_violations': 0},
#  159: {'best_fitness': -4.298996037255123,
#   'best_fitness_with_penalty': 7.545959908955807,
#   'weighted_penalty': 11.84495594621093,
#   'unweighted_penalty': 0.00016037928892290553,
#   'num_violations': 1},
#  160: {'best_fitness': -4.512589106232154,
#   'best_fitness_with_penalty': 7.349410893767846,
#   'weighted_penalty': 11.862,
#   'unweighted_penalty': 0,
#   'num_violations': 0},
#  161: {'best_fitness': -4.3452151232904175,
#   'best_fitness_with_penalty': 7.534784876709583,
#   'weighted_penalty': 11.88,
#   'unweighted_penalty': 0,
#   'num_violations': 0},
#  162: {'best_fitness': -4.348284654587963,
#   'best_fitness_with_penalty': 7.549715345412037,
#   'weighted_penalty': 11.898,
#   'unweighted_penalty': 0,
#   'num_violations': 0},
#  163: {'best_fitness': -4.541621903881285,
#   'best_fitness_with_penalty': 7.3874567495198695,
#   'weighted_penalty': 11.929078653401154,
#   'unweighted_penalty': 0.00214301480856338,
#   'num_violations': 2},
#  164: {'best_fitness': -4.800933274371889,
#   'best_fitness_with_penalty': 7.133066725628112,
#   'weighted_penalty': 11.934000000000001,
#   'unweighted_penalty': 0,
#   'num_violations': 0},
#  165: {'best_fitness': -4.983117406917486,
#   'best_fitness_with_penalty': 6.968882593082514,
#   'weighted_penalty': 11.952,
#   'unweighted_penalty': 0,
#   'num_violations': 0},
#  166: {'best_fitness': -4.999972244558096,
#   'best_fitness_with_penalty': 6.970301834127444,
#   'weighted_penalty': 11.97027407868554,
#   'unweighted_penalty': 4.440895356599183e-05,
#   'num_violations': 1},
#  167: {'best_fitness': -4.971271726969872,
#   'best_fitness_with_penalty': 7.01672827303013,
#   'weighted_penalty': 11.988000000000001,
#   'unweighted_penalty': 0,
#   'num_violations': 0},
#  168: {'best_fitness': -4.926897138489385,
#   'best_fitness_with_penalty': 7.0793047027057705,
#   'weighted_penalty': 12.006201841195155,
#   'unweighted_penalty': 3.2383614718726095e-05,
#   'num_violations': 1},
#  169: {'best_fitness': -5.358774697526163,
#   'best_fitness_with_penalty': 6.675508006024275,
#   'weighted_penalty': 12.034282703550438,
#   'unweighted_penalty': 0.0016369808522376553,
#   'num_violations': 2},
#  170: {'best_fitness': -5.188161277232826,
#   'best_fitness_with_penalty': 6.861431892923719,
#   'weighted_penalty': 12.049593170156545,
#   'unweighted_penalty': 0.0012039154976375736,
#   'num_violations': 2},
#  171: {'best_fitness': -5.571246170014598,
#   'best_fitness_with_penalty': 6.500145475068843,
#   'weighted_penalty': 12.071391645083441,
#   'unweighted_penalty': 0.0017953427218315176,
#   'num_violations': 2},
#  172: {'best_fitness': -5.834147561175528,
#   'best_fitness_with_penalty': 6.252599221999129,
#   'weighted_penalty': 12.086746783174657,
#   'unweighted_penalty': 0.0013728882488283644,
#   'num_violations': 2},
#  173: {'best_fitness': -6.1950271755518855,
#   'best_fitness_with_penalty': 5.906545804441642,
#   'weighted_penalty': 12.101572979993527,
#   'unweighted_penalty': 0.0008718537482397631,
#   'num_violations': 2},
#  174: {'best_fitness': -6.143484907747642,
#   'best_fitness_with_penalty': 5.977885478795183,
#   'weighted_penalty': 12.121370386542825,
#   'unweighted_penalty': 0.0011465003945011947,
#   'num_violations': 2},
#  175: {'best_fitness': -6.2200296411238885,
#   'best_fitness_with_penalty': 5.919789296642451,
#   'weighted_penalty': 12.13981893776634,
#   'unweighted_penalty': 0.00121049331923354,
#   'num_violations': 2},
#  176: {'best_fitness': -6.31682378254106,
#   'best_fitness_with_penalty': 5.8365007342176005,
#   'weighted_penalty': 12.15332451675866,
#   'unweighted_penalty': 0.0005125656679424987,
#   'num_violations': 2},
#  177: {'best_fitness': -6.047097304929812,
#   'best_fitness_with_penalty': 6.1248435563470185,
#   'weighted_penalty': 12.17194086127683,
#   'unweighted_penalty': 0.0006045670390824727,
#   'num_violations': 2},
#  178: {'best_fitness': -6.036877307995755,
#   'best_fitness_with_penalty': 6.154178047925307,
#   'weighted_penalty': 12.191055355921062,
#   'unweighted_penalty': 0.0007715709454584955,
#   'num_violations': 2},
#  179: {'best_fitness': -6.107824762016915,
#   'best_fitness_with_penalty': 6.125967804524074,
#   'weighted_penalty': 12.23379256654099,
#   'unweighted_penalty': 0.004494311290060856,
#   'num_violations': 2},
#  180: {'best_fitness': -5.970365431088371,
#   'best_fitness_with_penalty': 6.267480525418131,
#   'weighted_penalty': 12.237845956506503,
#   'unweighted_penalty': 0.002390090350932846,
#   'num_violations': 3},
#  181: {'best_fitness': -6.481495956233722,
#   'best_fitness_with_penalty': 5.761102837945771,
#   'weighted_penalty': 12.242598794179493,
#   'unweighted_penalty': 0.00039129937316606625,
#   'num_violations': 2},
#  182: {'best_fitness': -6.273125502763982,
#   'best_fitness_with_penalty': 5.985535647984623,
#   'weighted_penalty': 12.258661150748605,
#   'unweighted_penalty': 9.912840405285216e-05,
#   'num_violations': 1},
#  183: {'best_fitness': -6.175324244328788,
#   'best_fitness_with_penalty': 6.101271104627246,
#   'weighted_penalty': 12.276595348956034,
#   'unweighted_penalty': 8.884303733201692e-05,
#   'num_violations': 1},
#  184: {'best_fitness': -6.141704153517681,
#   'best_fitness_with_penalty': 6.152947798691347,
#   'weighted_penalty': 12.294651952209028,
#   'unweighted_penalty': 9.683384200566479e-05,
#   'num_violations': 2},
#  185: {'best_fitness': -5.9093794289818184,
#   'best_fitness_with_penalty': 6.403160339053951,
#   'weighted_penalty': 12.31253976803577,
#   'unweighted_penalty': 7.97985140495111e-05,
#   'num_violations': 2},
#  186: {'best_fitness': -6.74782221957157,
#   'best_fitness_with_penalty': 5.582454789835915,
#   'weighted_penalty': 12.330277009407485,
#   'unweighted_penalty': 4.076350130702517e-05,
#   'num_violations': 2},
#  187: {'best_fitness': -6.414086113710339,
#   'best_fitness_with_penalty': 5.93792357458048,
#   'weighted_penalty': 12.352009688290819,
#   'unweighted_penalty': 0.0005867054851852167,
#   'num_violations': 2},
#  188: {'best_fitness': -6.326428586502119,
#   'best_fitness_with_penalty': 6.04033303694916,
#   'weighted_penalty': 12.366761623451278,
#   'unweighted_penalty': 0.00011102533185486138,
#   'num_violations': 2},
#  189: {'best_fitness': -6.44669448568566,
#   'best_fitness_with_penalty': 5.938402460618596,
#   'weighted_penalty': 12.385096946304255,
#   'unweighted_penalty': 0.00015915644467906262,
#   'num_violations': 2},
#  190: {'best_fitness': -6.1648899464601135,
#   'best_fitness_with_penalty': 6.237177062549271,
#   'weighted_penalty': 12.402067009009384,
#   'unweighted_penalty': 9.678898906141665e-06,
#   'num_violations': 2},
#  191: {'best_fitness': -6.101896463830522,
#   'best_fitness_with_penalty': 6.31814605862265,
#   'weighted_penalty': 12.420042522453173,
#   'unweighted_penalty': 6.113688756475055e-06,
#   'num_violations': 1},
#  192: {'best_fitness': -5.996325879611201,
#   'best_fitness_with_penalty': 6.441694479864057,
#   'weighted_penalty': 12.438020359475258,
#   'unweighted_penalty': 2.9137273178978003e-06,
#   'num_violations': 1},
#  193: {'best_fitness': -6.146976417190682,
#   'best_fitness_with_penalty': 6.3113121075075735,
#   'weighted_penalty': 12.458288524698256,
#   'unweighted_penalty': 0.0003258008308221665,
#   'num_violations': 1},
#  194: {'best_fitness': -6.291358060318591,
#   'best_fitness_with_penalty': 6.186678585387171,
#   'weighted_penalty': 12.478036645705762,
#   'unweighted_penalty': 0.0005717599128784083,
#   'num_violations': 2},
#  195: {'best_fitness': -6.820106105958553,
#   'best_fitness_with_penalty': 5.678400074150694,
#   'weighted_penalty': 12.498506180109247,
#   'unweighted_penalty': 0.0009166956850412664,
#   'num_violations': 2},
#  196: {'best_fitness': -7.186920559209031,
#   'best_fitness_with_penalty': 5.333713142277012,
#   'weighted_penalty': 12.520633701486043,
#   'unweighted_penalty': 0.0014898151451724372,
#   'num_violations': 2},
#  197: {'best_fitness': -6.869430250086797,
#   'best_fitness_with_penalty': 5.66062022367724,
#   'weighted_penalty': 12.530050473764037,
#   'unweighted_penalty': 0.0002866481269781455,
#   'num_violations': 2},
#  198: {'best_fitness': -7.5562424776651005,
#   'best_fitness_with_penalty': 4.998166682676023,
#   'weighted_penalty': 12.554409160341123,
#   'unweighted_penalty': 0.0011685269455494669,
#   'num_violations': 2},
#  199: {'best_fitness': -7.47755591494346,
#   'best_fitness_with_penalty': 5.086535854638511,
#   'weighted_penalty': 12.564091769581971,
#   'unweighted_penalty': 1.2719799600613672e-05,
#   'num_violations': 2},
#  200: {'best_fitness': -7.396873293243392,
#   'best_fitness_with_penalty': 5.2080795815079615,
#   'weighted_penalty': 12.604952874751353,
#   'unweighted_penalty': 0.0031550516236745593,
#   'num_violations': 2},
#  201: {'best_fitness': -7.592353194613721,
#   'best_fitness_with_penalty': 5.009135942622568,
#   'weighted_penalty': 12.601489137236289,
#   'unweighted_penalty': 0.00020450549791472476,
#   'num_violations': 2},
#  202: {'best_fitness': -7.705290859040816,
#   'best_fitness_with_penalty': 4.914910056182015,
#   'weighted_penalty': 12.620200915222831,
#   'unweighted_penalty': 0.00030077544985865855,
#   'num_violations': 2},
#  203: {'best_fitness': -7.674991230328374,
#   'best_fitness_with_penalty': 4.962807968521256,
#   'weighted_penalty': 12.63779919884963,
#   'unweighted_penalty': 0.00024480447975537415,
#   'num_violations': 2},
#  204: {'best_fitness': -7.386142505148224,
#   'best_fitness_with_penalty': 5.2703088614169955,
#   'weighted_penalty': 12.65645136656522,
#   'unweighted_penalty': 0.00033200002287395283,
#   'num_violations': 2},
#  205: {'best_fitness': -7.427166833493872,
#   'best_fitness_with_penalty': 5.2479401292706696,
#   'weighted_penalty': 12.675106962764541,
#   'unweighted_penalty': 0.0004189273638494188,
#   'num_violations': 2},
#  206: {'best_fitness': -7.65257258237648,
#   'best_fitness_with_penalty': 5.039400657724044,
#   'weighted_penalty': 12.691973240100523,
#   'unweighted_penalty': 0.0002649223892725174,
#   'num_violations': 2},
#  207: {'best_fitness': -7.959237929715029,
#   'best_fitness_with_penalty': 5.033053369103622,
#   'weighted_penalty': 12.992291298818651,
#   'unweighted_penalty': 0.03530905446145903,
#   'num_violations': 3},
#  208: {'best_fitness': -7.847568799972947,
#   'best_fitness_with_penalty': 4.882335797884927,
#   'weighted_penalty': 12.729904597857875,
#   'unweighted_penalty': 0.0005193066743440953,
#   'num_violations': 2},
#  209: {'best_fitness': -7.681978591194417,
#   'best_fitness_with_penalty': 5.064367377425665,
#   'weighted_penalty': 12.746345968620082,
#   'unweighted_penalty': 0.00031080946713657985,
#   'num_violations': 2},
#  210: {'best_fitness': -7.582674511471891,
#   'best_fitness_with_penalty': 5.196649844021062,
#   'weighted_penalty': 12.779324355492953,
#   'unweighted_penalty': 0.0022786544301035766,
#   'num_violations': 2},
#  211: {'best_fitness': -7.665788037941974,
#   'best_fitness_with_penalty': 5.121823779849137,
#   'weighted_penalty': 12.787611817791111,
#   'unweighted_penalty': 0.0009979092395392508,
#   'num_violations': 2},
#  212: {'best_fitness': -7.86712291941238,
#   'best_fitness_with_penalty': 4.932020762978506,
#   'weighted_penalty': 12.799143682390886,
#   'unweighted_penalty': 0.00014955817148862074,
#   'num_violations': 2},
#  213: {'best_fitness': -7.69896272277486,
#   'best_fitness_with_penalty': 5.1308625380384445,
#   'weighted_penalty': 12.829825260813305,
#   'unweighted_penalty': 0.0017942388434491268,
#   'num_violations': 2},
#  214: {'best_fitness': -7.785519600240489,
#   'best_fitness_with_penalty': 5.049598309084287,
#   'weighted_penalty': 12.835117909324776,
#   'unweighted_penalty': 0.00014491457732419344,
#   'num_violations': 2},
#  215: {'best_fitness': -7.9068490962204345,
#   'best_fitness_with_penalty': 5.063289442388542,
#   'weighted_penalty': 12.970138538608976,
#   'unweighted_penalty': 0.014770878592389214,
#   'num_violations': 3},
#  216: {'best_fitness': -7.710729593997611,
#   'best_fitness_with_penalty': 5.1612785076902945,
#   'weighted_penalty': 12.872008101687905,
#   'unweighted_penalty': 0.0002579981150057316,
#   'num_violations': 2},
#  217: {'best_fitness': -7.40142270131352,
#   'best_fitness_with_penalty': 5.490216903161808,
#   'weighted_penalty': 12.891639604475328,
#   'unweighted_penalty': 0.00046535728746907937,
#   'num_violations': 1},
#  218: {'best_fitness': -7.722618071203108,
#   'best_fitness_with_penalty': 5.222423211841301,
#   'weighted_penalty': 12.945041283044409,
#   'unweighted_penalty': 0.004921007805993841,
#   'num_violations': 2},
#  219: {'best_fitness': -7.8408897262203885,
#   'best_fitness_with_penalty': 5.086201235249441,
#   'weighted_penalty': 12.92709096146983,
#   'unweighted_penalty': 0.00039202086329591504,
#   'num_violations': 2},
#  220: {'best_fitness': -7.687183944845165,
#   'best_fitness_with_penalty': 5.292474604089142,
#   'weighted_penalty': 12.979658548934307,
#   'unweighted_penalty': 0.004708609836826181,
#   'num_violations': 2},
#  221: {'best_fitness': -7.769062444738924,
#   'best_fitness_with_penalty': 5.228100468498611,
#   'weighted_penalty': 12.997162913237535,
#   'unweighted_penalty': 0.004628992763640844,
#   'num_violations': 2},
#  222: {'best_fitness': -7.8190588816512925,
#   'best_fitness_with_penalty': 5.167127984570689,
#   'weighted_penalty': 12.986186866221981,
#   'unweighted_penalty': 0.001023450818560174,
#   'num_violations': 2},
#  223: {'best_fitness': -7.822149117461689,
#   'best_fitness_with_penalty': 5.370409928525812,
#   'weighted_penalty': 13.192559045987501,
#   'unweighted_penalty': 0.02330019108132469,
#   'num_violations': 3},
#  224: {'best_fitness': -7.8990915434811315,
#   'best_fitness_with_penalty': 5.212333932769169,
#   'weighted_penalty': 13.1114254762503,
#   'unweighted_penalty': 0.01181971531379676,
#   'num_violations': 2},
#  225: {'best_fitness': -7.788632649756063,
#   'best_fitness_with_penalty': 5.274914571531867,
#   'weighted_penalty': 13.06354722128793,
#   'unweighted_penalty': 0.003880602321541443,
#   'num_violations': 2},
#  226: {'best_fitness': -7.789262558756362,
#   'best_fitness_with_penalty': 5.308588228736395,
#   'weighted_penalty': 13.097850787492757,
#   'unweighted_penalty': 0.005814669788498831,
#   'num_violations': 3},
#  227: {'best_fitness': -7.795650912982262,
#   'best_fitness_with_penalty': 5.4185252353043705,
#   'weighted_penalty': 13.214176148286633,
#   'unweighted_penalty': 0.017226719844669978,
#   'num_violations': 3},
#  228: {'best_fitness': -7.246642553021342,
#   'best_fitness_with_penalty': 5.860444707124508,
#   'weighted_penalty': 13.10708726014585,
#   'unweighted_penalty': 0.0025598712371700857,
#   'num_violations': 2},
#  229: {'best_fitness': -7.6130614092684485,
#   'best_fitness_with_penalty': 5.774098409746202,
#   'weighted_penalty': 13.38715981901465,
#   'unweighted_penalty': 0.03198416294819684,
#   'num_violations': 2},
#  230: {'best_fitness': -7.339311059826579,
#   'best_fitness_with_penalty': 5.836694182073924,
#   'weighted_penalty': 13.176005241900503,
#   'unweighted_penalty': 0.006443516388457749,
#   'num_violations': 2},
#  231: {'best_fitness': -7.442424836917669,
#   'best_fitness_with_penalty': 5.722528952151184,
#   'weighted_penalty': 13.164953789068853,
#   'unweighted_penalty': 0.002990176373871019,
#   'num_violations': 2},
#  232: {'best_fitness': -7.508283274328013,
#   'best_fitness_with_penalty': 5.652851862517224,
#   'weighted_penalty': 13.161135136845237,
#   'unweighted_penalty': 0.0003761452451888809,
#   'num_violations': 1},
#  233: {'best_fitness': -7.212035647171342,
#   'best_fitness_with_penalty': 5.964574139653728,
#   'weighted_penalty': 13.17660978682507,
#   'unweighted_penalty': 7.291373029070153e-05,
#   'num_violations': 2},
#  234: {'best_fitness': -7.440495244102757,
#   'best_fitness_with_penalty': 6.045214077744352,
#   'weighted_penalty': 13.485709321847109,
#   'unweighted_penalty': 0.032394320569093256,
#   'num_violations': 3},
#  235: {'best_fitness': -7.476529959958314,
#   'best_fitness_with_penalty': 5.737107067705588,
#   'weighted_penalty': 13.213637027663902,
#   'unweighted_penalty': 0.00019405088533351557,
#   'num_violations': 1},
#  236: {'best_fitness': -7.102243616638613,
#   'best_fitness_with_penalty': 6.144947720843594,
#   'weighted_penalty': 13.247191337482207,
#   'unweighted_penalty': 0.0020208475826261254,
#   'num_violations': 2},
#  237: {'best_fitness': -7.08096333043643,
#   'best_fitness_with_penalty': 6.170479648481815,
#   'weighted_penalty': 13.251442978918245,
#   'unweighted_penalty': 0.0004046196838411089,
#   'num_violations': 2},
#  238: {'best_fitness': -7.739824037140894,
#   'best_fitness_with_penalty': 5.527575743442987,
#   'weighted_penalty': 13.267399780583881,
#   'unweighted_penalty': 0.0001638941240207959,
#   'num_violations': 1},
#  239: {'best_fitness': -6.746655636538598,
#   'best_fitness_with_penalty': 6.542913455444793,
#   'weighted_penalty': 13.289569091983392,
#   'unweighted_penalty': 0.0006486723584329797,
#   'num_violations': 2},
#  240: {'best_fitness': -7.345614828377149,
#   'best_fitness_with_penalty': 6.041415950937834,
#   'weighted_penalty': 13.387030779314983,
#   'unweighted_penalty': 0.009650825521726265,
#   'num_violations': 1},
#  241: {'best_fitness': -7.0727996704841605,
#   'best_fitness_with_penalty': 6.247801283743565,
#   'weighted_penalty': 13.320600954227725,
#   'unweighted_penalty': 6.952255180848958e-05,
#   'num_violations': 2},
#  242: {'best_fitness': -6.704210214331638,
#   'best_fitness_with_penalty': 6.658165034310521,
#   'weighted_penalty': 13.36237524864216,
#   'unweighted_penalty': 0.0027958821243229217,
#   'num_violations': 2},
#  243: {'best_fitness': -6.700696004363908,
#   'best_fitness_with_penalty': 6.674129353516331,
#   'weighted_penalty': 13.374825357880239,
#   'unweighted_penalty': 0.002153300740560228,
#   'num_violations': 2},
#  244: {'best_fitness': -7.268497113462995,
#   'best_fitness_with_penalty': 6.144089733770219,
#   'weighted_penalty': 13.412586847233214,
#   'unweighted_penalty': 0.004382056784691718,
#   'num_violations': 2},
#  245: {'best_fitness': -6.322714828954988,
#   'best_fitness_with_penalty': 7.073370727837494,
#   'weighted_penalty': 13.396085556792482,
#   'unweighted_penalty': 0.0004646422956118583,
#   'num_violations': 2},
#  246: {'best_fitness': -7.493132230307372,
#   'best_fitness_with_penalty': 5.916867769692628,
#   'weighted_penalty': 13.41,
#   'unweighted_penalty': 0,
#   'num_violations': 0},
#  247: {'best_fitness': -6.901682619907121,
#   'best_fitness_with_penalty': 6.532512238804155,
#   'weighted_penalty': 13.434194858711276,
#   'unweighted_penalty': 0.0006982815165098293,
#   'num_violations': 2},
#  248: {'best_fitness': -6.570971376824421,
#   'best_fitness_with_penalty': 6.875030211991907,
#   'weighted_penalty': 13.446001588816328,
#   'unweighted_penalty': 1.7867343486164494e-07,
#   'num_violations': 2},
#  249: {'best_fitness': -6.840121670267534,
#   'best_fitness_with_penalty': 6.623882346666797,
#   'weighted_penalty': 13.46400401693433,
#   'unweighted_penalty': 4.49918493025631e-07,
#   'num_violations': 2},
#  250: {'best_fitness': -6.604415375064879,
#   'best_fitness_with_penalty': 6.882032271279843,
#   'weighted_penalty': 13.486447646344722,
#   'unweighted_penalty': 0.0004955534610168159,
#   'num_violations': 2}}

# %%
best_genes = a.best_chromosome.genes
print(best_genes)
# Out:
# array([6.19438771e-05, 6.56271114e-01, 0.00000000e+00, 5.90801339e-03,
#        9.94815775e-01, 1.00000000e+00, 1.00000000e+00, 1.00000000e+00,
#        9.23752710e-01, 0.00000000e+00, 2.84341883e+00, 2.44460020e-09,
#        0.00000000e+00])

# %% [markdown]
# ## Parallel Benchmark

# %%
import time
from concurrent.futures import ProcessPoolExecutor, as_completed

g_test_problems = ["G1", "G4", "G5", "G6"] 
g_results = {problem: {"DE+SR": [], "GA": []} for problem in g_test_problems}
g_unweighted_penalty = {problem: {"DE+SR": [], "GA": []} for problem in g_test_problems}
g_num_violations = {problem: {"DE+SR": [], "GA": []} for problem in g_test_problems}

def run_experiment(test_problem, i, method, penalty):
    g_n = test_problem[-1]
    a = Population(test_problem, config_file=f"inputs/params_g{g_n}.cfg", penalty=penalty)
    a.evolve(method)
    b = functions.dict_to_dataframe(a.generation_statistics)
    result = {
        "best_fitness": b["best_fitness"].iloc[-1],
        "unweighted_penalty": b["unweighted_penalty"].iloc[-1],
        "num_violations": b["num_violations"].iloc[-1],
    }
    return test_problem, method, result

with ProcessPoolExecutor() as executor:
    futures = []
    for test_problem in g_test_problems:
        for i in range(50):
            start_time = time.time()
            futures.append(executor.submit(run_experiment, test_problem, i, "DE+SR", False))
            elapsed_time = time.time() - start_time
            print(f'{test_problem} \t DE+SR \t Iter {i} \t {elapsed_time:2.2f}s')
        
        for i in range(50):
            start_time = time.time()
            futures.append(executor.submit(run_experiment, test_problem, i, "GA", True))
            elapsed_time = time.time() - start_time
            print(f'{test_problem} \t GA \t Iter {i} \t {elapsed_time:2.2f}s')

    for future in as_completed(futures):
        test_problem, method, result = future.result()
        g_results[test_problem][method].append(result["best_fitness"])
        g_unweighted_penalty[test_problem][method].append(result["unweighted_penalty"])
        g_num_violations[test_problem][method].append(result["num_violations"])
# Out:
# G1 	 "DE+SR" 	 Iter 0 	 0.10s
# G1 	 "DE+SR" 	 Iter 1 	 0.00s
# G1 	 "DE+SR" 	 Iter 2 	 0.00s
# G1 	 "DE+SR" 	 Iter 3 	 0.00s
# G1 	 "DE+SR" 	 Iter 4 	 0.00s
# G1 	 "DE+SR" 	 Iter 5 	 0.00s
# G1 	 "DE+SR" 	 Iter 6 	 0.00s
# G1 	 "DE+SR" 	 Iter 7 	 0.00s
# G1 	 "DE+SR" 	 Iter 8 	 0.00s
# G1 	 "DE+SR" 	 Iter 9 	 0.00s
# G1 	 "DE+SR" 	 Iter 10 	 0.00s
# G1 	 "DE+SR" 	 Iter 11 	 0.00s
# G1 	 "DE+SR" 	 Iter 12 	 0.00s
# G1 	 "DE+SR" 	 Iter 13 	 0.00s
